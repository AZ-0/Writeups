# %%
n = 
e = 65537
c = 

# %%
hex(n)
# Out:
# ''

# %%
n.nbits()
# Out:
# 1025

# %%
bin(n)
# Out:
# '...'

# %%
R.<x> = ZZ[]
[(p, _), (q, _)] = R(n.digits(2)).factor()

p(2).is_prime()
# Out:
# True

# %%
p = p(2)
q = q(2)

phi = (p-1)*(q-1)
d = inverse_mod(e, phi)
m = pow(c, d, n)
print(int(m).to_bytes(m.nbits()//8 + 1, 'big'))
# Out:
# b"\x02mF\x03\xb9\xe6(s\xb5\xd0\x88\xdd\xdc|N\n\xbbr\xb8~\x0cI\xce\xea{'\xc8\x7f\x1eS\x8dz\xbcf\x87\xb0\n+\xf2\x19=\x0f3\xef\xa8M'\x8f\x02}\xb8\x07\xee\xe7\xb3\\\xbd\x00FCSC{0224e979da8a6069869ccfc040abb680ffd35e3ba61bcc0e0683662c33fa81c0}"

# %%
n = ...
e = 65537
c = ...

# %%
print(*n.digits(128)[::-1], sep='')
# Out:
# 

# %%
R.<x> = ZZ[]
R(n.digits(2))
# Out:
# x^2048 + x^1870 + x^1861 + x^1792 + x^1744 + x^1690 + x^1682 + x^1613 + x^1605 + x^1565 + x^1521 + x^1488 + x^1482 + x^1477 + x^1476 + x^1425 + x^1381 + x^1377 + x^1342 + x^1333 + x^1303 + x^1298 + x^1297 + x^1295 + x^1291 + x^1289 + x^1264 + x^1246 + x^1238 + x^1221 + x^1216 + x^1202 + x^1198 + x^1196 + x^1194 + x^1178 + x^1172 + x^1122 + x^1112 + x^1104 + x^1077 + x^1025 + x^1017 + x^992 + x^987 + x^954 + x^949 + x^948 + x^940 + x^911 + x^905 + x^897 + x^854 + x^853 + x^849 + x^846 + x^837 + x^811 + x^810 + x^805 + x^768 + x^763 + x^754 + x^721 + x^710 + x^668 + x^630 + x^624 + x^620 + x^573 + x^529 + x^497 + x^458 + x^453 + x^452 + x^439 + x^401 + x^357 + x^353 + x^267 + x^172 + 1
